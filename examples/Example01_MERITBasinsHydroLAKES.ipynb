# %% [markdown]
# ## Datasets Used
#
# ### 1. MERIT-Basins
#
# **Description**
# A global reconstruction of naturalized river flows for approximately **2.94 million river reaches**, derived from the MERIT hydrography framework. The dataset provides a consistent global representation of river connectivity and flow characteristics suitable for large-scale hydrological modeling.
#
# > **Note:** A bug-fixed version of this dataset was used in the present work.
#
# **Citation**
# Lin, P., Pan, M., Beck, H. E., Yang, Y., Yamazaki, D., Frasson, R., *et al.* (2019).
# *Global reconstruction of naturalized river flows at 2.94 million reaches.*
# **Water Resources Research**, 55(8), 6499–6516.
# https://doi.org/10.1029/2019WR025287
#
# **Dataset Access**
# - MERIT-Basins Hydrography (based on MERIT-Hydro v0.7 / v1.0_bugfix1):
#   https://www.reachhydro.org/home/params/merit-basins
#   *(Includes minor bug fixes for coastline pixels)*
#
# ---
#
# ### 2. HydroLAKES (Version 1)
#
# **Description**
# A global vector database of lakes and reservoirs, providing detailed information on lake shorelines, surface area, volume, depth estimates, and hydrological connectivity. HydroLAKES is widely used in global hydrology and water resources studies.
#
# **Citation**
# Messager, M. L., Lehner, B., Grill, G., Nedeva, I., & Schmitt, O. (2016).
# *Estimating the volume and age of water stored in global lakes using a geostatistical approach.*
# **Nature Communications**, 7, 13603.
# https://doi.org/10.1038/ncomms13603
#
# **Dataset Access**
# - HydroLAKES product page:
#   https://www.hydrosheds.org/products/hydrolakes

# %% [markdown]
# ### Assigning parameters and folders

# %%
# outputfolder for where the files will be sitting
OutFolder = '/Users/shg096/Desktop/LakeRiverOut/MERITBasins/'

# location of MERIT-Basin bug fixed files
riv_file_template='/Users/shg096/Desktop/MERIT_Hydro/riv/riv_pfaf_*_MERIT_Hydro_v07_Basins_v01_bugfix1.shp',
cat_file_template='/Users/shg096/Desktop/MERIT_Hydro/cat/cat_pfaf_*_MERIT_Hydro_v07_Basins_v01_bugfix1.shp',
cst_file_template='/Users/shg096/Desktop/MERIT_Hydro/hill/hillslope_*_clean.shp'

# location of HydroLAKES
lake_file = '/Volumes/F:/hydrography/hydrolakes/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp'

# pfaf to be computed
pfafs = ["71","72","73","74"]

# %%
# load the needed packages
import os
import shutil
import geopandas as gpd
from   riverlakenetwork import Utility, BurnLakes
import warnings; warnings.filterwarnings("ignore")

# %%
#load hydrolakeDataset
lake = gpd.read_file(lake_file) # read the hydrolake dataset
# merge lake Michigan and Huron as they are hydraulically connected
lake = Utility.FixHydroLAKESv1(lake, merge_lakes={"Michigan+Huron": [6, 8]})

for pfaf in pfafs:

    pfaf_base = f"pfaf{pfaf}"

    # create the folder if not existed
    org_folder = os.path.join(OutFolder, f"{pfaf_base}_org")
    if os.path.isdir(org_folder):
        try:
            shutil.rmtree(org_folder)
        except OSError as e:
            raise RuntimeError(f"Failed to remove {org_folder}: {e}")
    os.makedirs(org_folder, exist_ok=True)
    
    # read the pfaf merit folder
    riv, cat = Utility.merit_read_file(pfaf,
                                       riv_file_template='/Users/shg096/Desktop/MERIT_Hydro/riv/riv_pfaf_*_MERIT_Hydro_v07_Basins_v01_bugfix1.shp',
                                       cat_file_template='/Users/shg096/Desktop/MERIT_Hydro/cat/cat_pfaf_*_MERIT_Hydro_v07_Basins_v01_bugfix1.shp',
                                       cst_file_template='/Users/shg096/Desktop/MERIT_Hydro/hill/hillslope_*_clean.shp')
    # save riv and cat
    riv.to_file(os.path.join(org_folder, "riv.gpkg"))
    cat.to_file(os.path.join(org_folder, "cat.gpkg"))

    # create the folder if not existed
    corrected_folder = os.path.join(OutFolder, f"{pfaf_base}_corrected")
    if os.path.isdir(corrected_folder):
        try:
            shutil.rmtree(corrected_folder)
        except OSError as e:
            raise RuntimeError(f"Failed to remove {corrected_folder}: {e}")
    os.makedirs(corrected_folder, exist_ok=True)
    
    # create the config and pass it to the Burn lake
    config = {
        "riv": riv,
        "riv_dict": {
            "COMID": {"col":"COMID"},
            "NextDownCOMID": {"col":"NextDownID"},
            "length": {"col":"lengthkm"},
            "uparea": {"col":"uparea","unit":"km2"}
        },
        "cat": cat,
        "cat_dict": {
            "COMID": {"col":"COMID"},
            "unitarea": {"col":"unitarea","unit":"km2"},
        },
        "lake": lake,
        "lake_dict": {
            "LakeCOMID": {"col":"Hylak_id"},
            "unitarea": {"col":"Lake_area","unit":"km2"}
        },
    }
    
    bl = BurnLakes(config)
    bl.riv.to_file(os.path.join(corrected_folder, "riv.gpkg"))
    bl.cat.to_file(os.path.join(corrected_folder, "cat.gpkg"))
    bl.lake.to_file(os.path.join(corrected_folder, "lake.gpkg"))
# Out:
# =======================================================================
# === Input loader started at : 2025-12-19 21:20:30  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2025-12-19 21:20:31  ===
# === Input loader took      : 0:00:00.615585  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2025-12-19 21:20:31  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# === Input checker finished at: 2025-12-19 21:20:32  ===
# === Input checker took      : 0:00:00.782039  ===========================
# ========================================================================
# ==========================================================================
# === Resolving lakes started at : 2025-12-19 21:20:32  ===
# ==== Number of lakes after subsetting: 140586 ====
# ==== Number of lakes after removing intersection with only one lake: 5202 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 4069 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 4007 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 4007 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 4007 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 4006 ====
# ==== Number of lakes after identifying the graph number within a lake: 3999 ====
# === Resolving lakes finished at: 2025-12-19 21:27:27  ===
# === Resolving lakes took      : 0:06:55.642909  ===========================
# ==========================================================================
# =============================================================================
# === Network correction started at : 2025-12-19 21:27:27  ===
# === Network correction finished at: 2025-12-19 21:32:53  ===
# === Network correction took      : 0:05:25.611117  ===========================
# =============================================================================
# =============================================================================
# === Output checker started at : 2025-12-19 21:32:53  =======
# ✓ No lake outlet topology issues found.
# []
# []
# === Output checker finished at: 2025-12-19 21:32:58  ===
# === Output checker took      : 0:00:04.889715  ===========================
# =========================================================================
# =======================================================================
# === Input loader started at : 2025-12-19 21:33:38  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2025-12-19 21:33:40  ===
# === Input loader took      : 0:00:02.335599  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2025-12-19 21:33:40  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# === Input checker finished at: 2025-12-19 21:33:41  ===
# === Input checker took      : 0:00:01.131067  ===========================
# ========================================================================
# ==========================================================================
# === Resolving lakes started at : 2025-12-19 21:33:41  ===
# ==== Number of lakes after subsetting: 264384 ====
# ==== Number of lakes after removing intersection with only one lake: 10065 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 6434 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 6219 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 6219 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 6219 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 6218 ====
# ==== Number of lakes after identifying the graph number within a lake: 6213 ====
# === Resolving lakes finished at: 2025-12-19 21:59:01  ===
# === Resolving lakes took      : 0:25:20.402008  ===========================
# ==========================================================================
# =============================================================================
# === Network correction started at : 2025-12-19 21:59:01  ===
# === Network correction finished at: 2025-12-19 22:15:04  ===
# === Network correction took      : 0:16:02.106294  ===========================
# =============================================================================
# =============================================================================
# === Output checker started at : 2025-12-19 22:15:04  =======
# ✓ No lake outlet topology issues found.
# []
# []
# === Output checker finished at: 2025-12-19 22:15:13  ===
# === Output checker took      : 0:00:09.596944  ===========================
# =========================================================================
# =======================================================================
# === Input loader started at : 2025-12-19 22:16:50  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2025-12-19 22:16:52  ===
# === Input loader took      : 0:00:01.970009  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2025-12-19 22:16:52  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# === Input checker finished at: 2025-12-19 22:16:53  ===
# === Input checker took      : 0:00:00.541556  ===========================
# ========================================================================
# ==========================================================================
# === Resolving lakes started at : 2025-12-19 22:16:53  ===
# ==== Number of lakes after subsetting: 9582 ====
# ==== Number of lakes after removing intersection with only one lake: 605 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 501 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 492 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 492 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 492 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 492 ====
# ==== Number of lakes after identifying the graph number within a lake: 492 ====
# === Resolving lakes finished at: 2025-12-19 22:17:42  ===
# === Resolving lakes took      : 0:00:49.382783  ===========================
# ==========================================================================
# =============================================================================
# === Network correction started at : 2025-12-19 22:17:42  ===
# === Network correction finished at: 2025-12-19 22:18:38  ===
# === Network correction took      : 0:00:55.469362  ===========================
# =============================================================================
# =============================================================================
# === Output checker started at : 2025-12-19 22:18:38  =======
# ✓ No lake outlet topology issues found.
# []
# []
# === Output checker finished at: 2025-12-19 22:18:40  ===
# === Output checker took      : 0:00:02.297354  ===========================
# =========================================================================
# =======================================================================
# === Input loader started at : 2025-12-19 22:18:57  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2025-12-19 22:19:01  ===
# === Input loader took      : 0:00:03.449699  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2025-12-19 22:19:01  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# === Input checker finished at: 2025-12-19 22:19:03  ===
# === Input checker took      : 0:00:02.775881  ===========================
# ========================================================================
# ==========================================================================
# === Resolving lakes started at : 2025-12-19 22:19:03  ===
# ==== Number of lakes after subsetting: 19997 ====
# ==== Number of lakes after removing intersection with only one lake: 1654 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 1307 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 1277 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 1277 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 1277 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 1277 ====
# ==== Number of lakes after identifying the graph number within a lake: 1271 ====
# === Resolving lakes finished at: 2025-12-19 22:23:26  ===
# === Resolving lakes took      : 0:04:22.532505  ===========================
# ==========================================================================
# =============================================================================
# === Network correction started at : 2025-12-19 22:23:26  ===
# === Network correction finished at: 2025-12-19 22:26:52  ===
# === Network correction took      : 0:03:26.016580  ===========================
# =============================================================================
# =============================================================================
# === Output checker started at : 2025-12-19 22:26:52  =======
# ✓ No lake outlet topology issues found.
# []
# []
# === Output checker finished at: 2025-12-19 22:26:57  ===
# === Output checker took      : 0:00:05.105928  ===========================
# =========================================================================
