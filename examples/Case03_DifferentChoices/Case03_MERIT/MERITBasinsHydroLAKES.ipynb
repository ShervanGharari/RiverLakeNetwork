# %% [markdown]
# ## Datasets Used
#
# ### 1. MERIT-Basins
#
# **Description**
# A global reconstruction of naturalized river flows for approximately **2.94 million river reaches**, derived from the MERIT hydrography framework. The dataset provides a consistent global representation of river connectivity and flow characteristics suitable for large-scale hydrological modeling.
#
# > **Note:** A bug-fixed version of this dataset was used in the present work.
#
# **Citation**
# Lin, P., Pan, M., Beck, H. E., Yang, Y., Yamazaki, D., Frasson, R., *et al.* (2019).
# *Global reconstruction of naturalized river flows at 2.94 million reaches.*
# **Water Resources Research**, 55(8), 6499–6516.
# https://doi.org/10.1029/2019WR025287
#
# **Dataset Access**
# - MERIT-Basins Hydrography (based on MERIT-Hydro v0.7 / v1.0_bugfix1):
#   https://www.reachhydro.org/home/params/merit-basins
#   *(Includes minor bug fixes for coastline pixels)*
#
# ---
#
# ### 2. HydroLAKES (Version 1)
#
# **Description**
# A global vector database of lakes and reservoirs, providing detailed information on lake shorelines, surface area, volume, depth estimates, and hydrological connectivity. HydroLAKES is widely used in global hydrology and water resources studies.
#
# **Citation**
# Messager, M. L., Lehner, B., Grill, G., Nedeva, I., & Schmitt, O. (2016).
# *Estimating the volume and age of water stored in global lakes using a geostatistical approach.*
# **Nature Communications**, 7, 13603.
# https://doi.org/10.1038/ncomms13603
#
# **Dataset Access**
# - HydroLAKES product page:
#   https://www.hydrosheds.org/products/hydrolakes

# %% [markdown]
# ### Assigning parameters and folders

# %%
# outputfolder for where the files will be sitting
OutFolder = '/Users/shg096/Desktop/LakeRiverOut/MERITBasins/'

regions = {
    "71": {
        "files": {
            "riv": "/Users/shg096/Desktop/MERIT_Hydro/riv/riv_pfaf_71_MERIT_Hydro_v07_Basins_v01_bugfix1.shp",
            "cat": "/Users/shg096/Desktop/MERIT_Hydro/cat/cat_pfaf_71_MERIT_Hydro_v07_Basins_v01_bugfix1.shp",
            "cst": "/Users/shg096/Desktop/MERIT_Hydro/hill/hillslope_71_clean.shp",
        }
    }
}

# combinations of flags
force_options = [True, False]
single_options = [False, True]
suffixes = ["a", "b", "c", "d"]

# location of HydroLAKES
lake_file = '/Volumes/F:/hydrography/hydrolakes/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp'

# %%
# load the needed packages
import os
import shutil
import geopandas as gpd
from   itertools import product
from   riverlakenetwork import Utility, BurnLakes
import warnings; warnings.filterwarnings("ignore")

# %%
#load hydrolakeDataset
lake = gpd.read_file(lake_file) # read the hydrolake dataset
# merge lake Michigan and Huron as they are hydraulically connected
lake = Utility.FixHydroLAKESv1(lake, merge_lakes={"Michigan+Huron": [6, 8]})
lake = lake.set_crs("EPSG:4326") # make sure the lake has projection

# %%
# ----------------------------------
# Loop
# ----------------------------------
for pfaf, region_data in regions.items():

    files = region_data["files"]

    for (force_flag, single_flag), suffix in zip(product(force_options, single_options), suffixes):

        pfaf_name = f"{pfaf}{suffix}"
        print(f"Running {pfaf_name} | force={force_flag} | single={single_flag}")

        # ----------------------------------
        # Read data
        # ----------------------------------
        riv, cat = Utility.merit_read_file(
            riv_file=files["riv"],
            cat_file=files["cat"],
            cst_file=files["cst"]
        )

        # ----------------------------------
        # Output folders
        # ----------------------------------
        def reset_folder(path):
            if os.path.isdir(path):
                shutil.rmtree(path)
            os.makedirs(path, exist_ok=True)

        org_folder = os.path.join(OutFolder, f"pfaf{pfaf_name}_org")
        corrected_folder = os.path.join(OutFolder, f"pfaf{pfaf_name}_corrected")

        reset_folder(org_folder)
        reset_folder(corrected_folder)

        # ----------------------------------
        # Manual fix (only if needed)
        # ----------------------------------
        riv.loc[riv["COMID"] == 74030207,
                ["NextDownID", "geometry", "maxup", "up1", "lengthkm"]] = [-9999, None, 0, 0, 0]

        # ----------------------------------
        # CRS
        # ----------------------------------
        riv = riv.set_crs("EPSG:4326")
        cat = cat.set_crs("EPSG:4326")

        # ----------------------------------
        # Save original
        # ----------------------------------
        riv.to_file(os.path.join(org_folder, "riv.gpkg"))
        cat.to_file(os.path.join(org_folder, "cat.gpkg"))

        # ----------------------------------
        # Config
        # ----------------------------------
        config = {
            "riv": riv,
            "riv_dict": {
                "COMID": {"col": "COMID"},
                "NextDownCOMID": {"col": "NextDownID"},
                "length": {"col": "lengthkm"},
                "uparea": {"col": "uparea", "unit": "km2"},
            },
            "cat": cat,
            "cat_dict": {
                "COMID": {"col": "COMID"},
                "unitarea": {"col": "unitarea", "unit": "km2"},
            },
            "lake": lake,
            "lake_dict": {
                "LakeCOMID": {"col": "Hylak_id"},
                "unitarea": {"col": "Lake_area", "unit": "km2"},
            },
        }

        # ----------------------------------
        # Run model
        # ----------------------------------
        bl = BurnLakes(
            InputData=config,
            EnforceOneLakePerSegment=force_flag,
            SingleSegmentProcessing=single_flag
        )

        # ----------------------------------
        # Save outputs
        # ----------------------------------
        bl.riv.to_file(os.path.join(corrected_folder, "riv.gpkg"))
        bl.cat.to_file(os.path.join(corrected_folder, "cat.gpkg"))
        bl.lake.to_file(os.path.join(corrected_folder, "lake.gpkg"))
# Out:
# Running 71a | force=True | single=False
# =======================================================================
# === Input loader started at : 2026-07-14 22:34:59  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2026-07-14 22:34:59  ===
# === Input loader took      : 0:00:00.504708  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2026-07-14 22:34:59  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# ✅ No loop detected in network topology
# === Input checker finished at: 2026-07-14 22:35:07  ===
# === Input checker took      : 0:00:07.587508  ===========================
# ========================================================================
# ==========================================================================================
# === Identifying multi-segment lakes started at : 2026-07-14 22:35:07  ===
# ==== Number of lakes after subsetting: 140586 ====
# ==== Number of lakes after removing intersection with only one lake: 5202 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 4069 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 4007 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 4007 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 4007 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 4006 ====
# ==== Number of lakes after enforcing one lake per river segment: 2171 ====
# ==== Number of lakes after identifying the graph number within a lake: 2164 ====
# === Identifying multi-segment lakes finished at: 2026-07-14 22:42:30  ===
# === Identifying multi-segment lakes took      : 0:07:23.463705  ===========================
# ==========================================================================================
# ==============================================================================================================
# === Network topology correction for multi-segment lakes started at : 2026-07-14 22:42:30  ===
# === Network topology correction for multi-segment lakes finished at: 2026-07-14 22:50:02  ===
# === Network topoloty correction for multi-segment lakes took      : 0:07:31.756557  ===========================
# ==============================================================================================================
# =============================================================================
# === Output checker started at : 2026-07-14 22:50:02  ===
# ✓ No lake outlet topology issues found.
#
# ⚠️ Upstream area differences exceeding tolerance detected.
#   25 segments exceed 1.00%.
#   36206 segments compared.
#   14132 skipped due to topology changes.
#   2164 COMIDs missing from original network, possibly masked by lakes.
#
#   Results stored in self.riv:
#     - uparea_diff
#     - uparea_diff_frac
#     - uparea_diff_perc
#
#   The detected differences may result from discrepancies between subbasin unit-area calculations and lake/reservoir unit-area calculations. To reduce these differences, please recalculate the unit areas consistently for subbasins, lakes, and river segments, and update the upstream contributing areas for the corrected river network topology using Utility.compute_uparea functionality before rerunning the workflow.
# ✅ No loop detected in network topology
# === Output checker finished at: 2026-07-14 22:51:09  ===
# === Output checker took      : 0:01:06.864953  ===========================
# =============================================================================
# Running 71b | force=True | single=True
# =======================================================================
# === Input loader started at : 2026-07-14 22:51:57  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2026-07-14 22:52:03  ===
# === Input loader took      : 0:00:06.046841  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2026-07-14 22:52:03  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# ✅ No loop detected in network topology
# === Input checker finished at: 2026-07-14 22:52:16  ===
# === Input checker took      : 0:00:12.723689  ===========================
# ========================================================================
# ==========================================================================================
# === Identifying multi-segment lakes started at : 2026-07-14 22:52:16  ===
# ==== Number of lakes after subsetting: 140586 ====
# ==== Number of lakes after removing intersection with only one lake: 5202 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 4069 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 4007 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 4007 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 4007 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 4006 ====
# ==== Number of lakes after enforcing one lake per river segment: 2171 ====
# ==== Number of lakes after identifying the graph number within a lake: 2164 ====
# === Identifying multi-segment lakes finished at: 2026-07-14 22:59:50  ===
# === Identifying multi-segment lakes took      : 0:07:34.001165  ===========================
# ==========================================================================================
# ==============================================================================================================
# === Network topology correction for multi-segment lakes started at : 2026-07-14 22:59:50  ===
# === Network topology correction for multi-segment lakes finished at: 2026-07-14 23:08:17  ===
# === Network topoloty correction for multi-segment lakes took      : 0:08:27.353614  ===========================
# ==============================================================================================================
# ===========================================================================================
# === Identifying single-segment lakes started at : 2026-07-14 23:08:17  ===
# ==== Number of single segment lakes after subsetting: 10482 ====
# ==== Number of lakes after processing: 6760 ====
# === Identifying single-segment lakes finished at : 2026-07-14 23:13:32  ===
# === Identifying single-segment lakes took        : 0:05:14.868959  ==========================
# ============================================================================================
# ===============================================================================================================
# === Network topology correction for single-segment lakes started at : 2026-07-14 23:13:32  ===
# === Network topology correction for single-segment lakes finished at: 2026-07-14 23:37:43  ===
# === Network topology correction for single-segment lakes took      : 0:24:11.460623  ===========================
# ===============================================================================================================
# =============================================================================
# === Output checker started at : 2026-07-14 23:37:43  ===
# ✓ No lake outlet topology issues found.
#
# ⚠️ Upstream area differences exceeding tolerance detected.
#   11 segments exceed 1.00%.
#   25804 segments compared.
#   24534 skipped due to topology changes.
#   8922 COMIDs missing from original network, possibly masked by lakes.
#
#   Results stored in self.riv:
#     - uparea_diff
#     - uparea_diff_frac
#     - uparea_diff_perc
#
#   The detected differences may result from discrepancies between subbasin unit-area calculations and lake/reservoir unit-area calculations. To reduce these differences, please recalculate the unit areas consistently for subbasins, lakes, and river segments, and update the upstream contributing areas for the corrected river network topology using Utility.compute_uparea functionality before rerunning the workflow.
# ✅ No loop detected in network topology
# === Output checker finished at: 2026-07-14 23:38:44  ===
# === Output checker took      : 0:01:00.416261  ===========================
# =============================================================================
# Running 71c | force=False | single=False
# =======================================================================
# === Input loader started at : 2026-07-14 23:39:43  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2026-07-14 23:39:46  ===
# === Input loader took      : 0:00:03.353503  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2026-07-14 23:39:46  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# ✅ No loop detected in network topology
# === Input checker finished at: 2026-07-14 23:39:57  ===
# === Input checker took      : 0:00:10.728848  ===========================
# ========================================================================
# ==========================================================================================
# === Identifying multi-segment lakes started at : 2026-07-14 23:39:57  ===
# ==== Number of lakes after subsetting: 140586 ====
# ==== Number of lakes after removing intersection with only one lake: 5202 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 4069 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 4007 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 4007 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 4007 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 4006 ====
# ==== Number of lakes after identifying the graph number within a lake: 3999 ====
# === Identifying multi-segment lakes finished at: 2026-07-14 23:47:52  ===
# === Identifying multi-segment lakes took      : 0:07:54.727383  ===========================
# ==========================================================================================
# ==============================================================================================================
# === Network topology correction for multi-segment lakes started at : 2026-07-14 23:47:52  ===
# === Network topology correction for multi-segment lakes finished at: 2026-07-14 23:54:23  ===
# === Network topoloty correction for multi-segment lakes took      : 0:06:31.205529  ===========================
# ==============================================================================================================
# =============================================================================
# === Output checker started at : 2026-07-14 23:54:23  ===
# ✓ No lake outlet topology issues found.
#
# ⚠️ Upstream area differences exceeding tolerance detected.
#   5 segments exceed 1.00%.
#   30573 segments compared.
#   19718 skipped due to topology changes.
#   3999 COMIDs missing from original network, possibly masked by lakes.
#
#   Results stored in self.riv:
#     - uparea_diff
#     - uparea_diff_frac
#     - uparea_diff_perc
#
#   The detected differences may result from discrepancies between subbasin unit-area calculations and lake/reservoir unit-area calculations. To reduce these differences, please recalculate the unit areas consistently for subbasins, lakes, and river segments, and update the upstream contributing areas for the corrected river network topology using Utility.compute_uparea functionality before rerunning the workflow.
# ✅ No loop detected in network topology
# === Output checker finished at: 2026-07-14 23:55:18  ===
# === Output checker took      : 0:00:54.919489  ===========================
# =============================================================================
# Running 71d | force=False | single=True
# =======================================================================
# === Input loader started at : 2026-07-14 23:56:03  ===
# riv: Loaded
# riv_dict: {'COMID': {'col': 'COMID'}, 'NextDownCOMID': {'col': 'NextDownID'}, 'length': {'col': 'lengthkm'}, 'uparea': {'col': 'uparea', 'unit': 'km2'}}
# cat: Loaded
# cat_dict: {'COMID': {'col': 'COMID'}, 'unitarea': {'col': 'unitarea', 'unit': 'km2'}}
# lake: Loaded
# lake_dict: {'LakeCOMID': {'col': 'Hylak_id'}, 'unitarea': {'col': 'Lake_area', 'unit': 'km2'}}
# === Input loader finished at: 2026-07-14 23:56:04  ===
# === Input loader took      : 0:00:01.048915  ===========================
# =======================================================================
# ========================================================================
# === Input checker started at : 2026-07-14 23:56:04  ===
# Subbasin and lake area units are consistent: km2
# riv CRS: EPSG:4326
# cat CRS: EPSG:4326
# lake CRS: EPSG:4326
# ✅ No loop detected in network topology
# === Input checker finished at: 2026-07-14 23:56:14  ===
# === Input checker took      : 0:00:10.658352  ===========================
# ========================================================================
# ==========================================================================================
# === Identifying multi-segment lakes started at : 2026-07-14 23:56:14  ===
# ==== Number of lakes after subsetting: 140586 ====
# ==== Number of lakes after removing intersection with only one lake: 5202 ====
# ==== Number of lakes after removing lakes that do not touch starting or ending points of river segments: 4069 ====
# ==== Number of lakes after removing lakes that do touch only one starting or ending points of river segments: 4007 ====
# ==== Number of lakes after removing lakes that do intersect with only one river segment: 4007 ====
# ==== Number of lakes after removing lakes that do have exactly the same uparea for their maximume uparea for various: 4007 ====
# ==== Number of lakes after removing lakes from segments that intersect with more than 3 lakes: 4006 ====
# ==== Number of lakes after identifying the graph number within a lake: 3999 ====
# === Identifying multi-segment lakes finished at: 2026-07-15 00:04:01  ===
# === Identifying multi-segment lakes took      : 0:07:46.560771  ===========================
# ==========================================================================================
# ==============================================================================================================
# === Network topology correction for multi-segment lakes started at : 2026-07-15 00:04:01  ===
# === Network topology correction for multi-segment lakes finished at: 2026-07-15 00:10:30  ===
# === Network topoloty correction for multi-segment lakes took      : 0:06:29.678991  ===========================
# ==============================================================================================================
# ===========================================================================================
# === Identifying single-segment lakes started at : 2026-07-15 00:10:30  ===
# ==== Number of single segment lakes after subsetting: 10482 ====
# ==== Number of lakes after processing: 5386 ====
# === Identifying single-segment lakes finished at : 2026-07-15 00:12:56  ===
# === Identifying single-segment lakes took        : 0:02:25.670749  ==========================
# ============================================================================================
# ===============================================================================================================
# === Network topology correction for single-segment lakes started at : 2026-07-15 00:12:56  ===
# === Network topology correction for single-segment lakes finished at: 2026-07-15 00:33:55  ===
# === Network topology correction for single-segment lakes took      : 0:20:59.309968  ===========================
# ===============================================================================================================
# =============================================================================
# === Output checker started at : 2026-07-15 00:33:55  ===
# ✓ No lake outlet topology issues found.
# ✓ Upstream areas consistent within 1.00% tolerance.
#   22952 segments compared.
#   27339 skipped due to topology changes.
#   9383 COMIDs missing from original network possibily masked by lakes.
# ✅ No loop detected in network topology
# === Output checker finished at: 2026-07-15 00:34:56  ===
# === Output checker took      : 0:01:00.440982  ===========================
# =============================================================================
