# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import hydrant.topology.geom as gm
import subprocess
import os
from   shapely.geometry import Point

# %%
# load the shapefile for infused lake and reservoir
riv = gpd.read_file('/Users/shg096/Desktop/LakeRiverOut/domain/pfaf71/pfaf71/riv.gpkg')
# load the shapefile for the 
cat = gpd.read_file('/Users/shg096/Desktop/LakeRiverOut/domain/pfaf71/pfaf71/cat.gpkg')
# load the entire lake from hydrolakes
lake = gpd.read_file('/Volumes/F:/hydrography/hydrolakes/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10_shp/HydroLAKES_polys_v10.shp')
